# %% [markdown]
# ![2560px-Pandas_logo.svg.png](attachment:2560px-Pandas_logo.svg.png)

# %% [markdown]
# <h1>#29 Melakukan random sampling pada Data Frame

# %%
#Import Modules

import pandas as pd

print(pd.__version__)
# Out:
# 1.3.3

# %% [markdown]
# <h3> Persiapan Data Frame

# %%
d = {'col_1':[1,2,3,4,5],
     'col_2':[10,20,30,40,50]}
df = pd.DataFrame(d)
df
# Out:
#    col_1  col_2
# 0      1     10
# 1      2     20
# 2      3     30
# 3      4     40
# 4      5     50

# %% [markdown]
# <h3> Random sampling with/without replacement

# %%
df.sample(n=4, replace=False, random_state=0)
# Out:
#    col_1  col_2
# 2      3     30
# 0      1     10
# 1      2     20
# 3      4     40

# %%
df.sample(n=4, replace=True, random_state=0)
# Out:
#    col_1  col_2
# 4      5     50
# 0      1     10
# 3      4     40
# 3      4     40

# %% [markdown]
# <h1>#30 Akses nilai variable pada query()

# %%
#Import Modules

import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.3
# 1.21.2

# %% [markdown]
# <h3> Persiapan Data Frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1,20, size =(n_rows, n_cols)),
                  columns=cols)
df
# Out:
#     A   B   C   D   E
# 0  19   7  16   9   4
# 1  11   5   7   1  19
# 2  11   7   6   7   2
# 3  13  15  17  10   9
# 4   2   2  11   4  17

# %% [markdown]
# <h3> Akses nilai varialbe pada query()

# %%
df.query('A > 5')
# Out:
#     A   B   C   D   E
# 0  19   7  16   9   4
# 1  11   5   7   1  19
# 2  11   7   6   7   2
# 3  13  15  17  10   9

# %%
rerata = df['A'].mean()
rerata
# Out:
# 11.2

# %%
df.query('A > @rerata' )
# Out:
#     A   B   C   D  E
# 0  19   7  16   9  4
# 3  13  15  17  10  9

# %% [markdown]
# <h1>#31 Mengenal tipe data ordinal pada Pandas

# %%
#Import Modules

import pandas as pd

print(pd.__version__)
# Out:
# 1.3.3

# %% [markdown]
# <h3> Persiapan Data Frame

# %%
d = {'pelanggan':[11,12,13,14],
     'kepuasan':['baik','cukup','buruk','cukup']}

df = pd.DataFrame(d)
df
# Out:
#    pelanggan kepuasan
# 0         11     baik
# 1         12    cukup
# 2         13    buruk
# 3         14    cukup

# %% [markdown]
# <h3> Tipe data ordinal pada Pandas

# %%
from pandas.api.types import CategoricalDtype

tingkat_kepuasan = CategoricalDtype(['buruk','cukup','baik','sangat baik'],
                                    ordered=True)

df['kepuasan'] = df['kepuasan'].astype(tingkat_kepuasan)
df
# Out:
#    pelanggan kepuasan
# 0         11     baik
# 1         12    cukup
# 2         13    buruk
# 3         14    cukup

# %%
df = df.sort_values('kepuasan', ascending=True)
df
# Out:
#    pelanggan kepuasan
# 2         13    buruk
# 1         12    cukup
# 3         14    cukup
# 0         11     baik

# %%
df[df['kepuasan'] >= 'cukup']
# Out:
#    pelanggan kepuasan
# 1         12    cukup
# 3         14    cukup
# 0         11     baik

# %% [markdown]
# <h1>#32 Plotting dari suatu Pandas Data Frame

# %%
#Import Modules

import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.3
# 1.21.2

# %% [markdown]
# <h3> Persiapan Data Frame

# %%
n_rows = 40
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1,20, size=(n_rows, n_cols)),
                  columns=cols)
df.head()
# Out:
#     A   B   C   D   E
# 0  19   6  12  17  18
# 1  16   4   4   5   4
# 2   7  12   7   1  12
# 3  15  11  19  15  17
# 4   5   4  12  12   4

# %% [markdown]
# <h3> Line PLot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   6  12  17  18
# 1  16   4   4   5   4
# 2   7  12   7   1  12
# 3  15  11  19  15  17
# 4   5   4  12  12   4

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].plot(kind='line')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3> Bar Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   6  12  17  18
# 1  16   4   4   5   4
# 2   7  12   7   1  12
# 3  15  11  19  15  17
# 4   5   4  12  12   4

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].head().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3> Area Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   6  12  17  18
# 1  16   4   4   5   4
# 2   7  12   7   1  12
# 3  15  11  19  15  17
# 4   5   4  12  12   4

# %%
df.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df[['A','B']].head().plot(kind='area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>Box Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   6  12  17  18
# 1  16   4   4   5   4
# 2   7  12   7   1  12
# 3  15  11  19  15  17
# 4   5   4  12  12   4

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3> Histogram

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   6  12  17  18
# 1  16   4   4   5   4
# 2   7  12   7   1  12
# 3  15  11  19  15  17
# 4   5   4  12  12   4

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['A','B']].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# <h3> Kernel Density Estimation (KDE)

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   6  12  17  18
# 1  16   4   4   5   4
# 2   7  12   7   1  12
# 3  15  11  19  15  17
# 4   5   4  12  12   4

# %%
df.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# <h3> Scatter Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  19   6  12  17  18
# 1  16   4   4   5   4
# 2   7  12   7   1  12
# 3  15  11  19  15  17
# 4   5   4  12  12   4

# %%
df.plot(x='A', y='B', kind='scatter')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>
